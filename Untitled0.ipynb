# %% [markdown]
# <a href="https://colab.research.google.com/github/Jenish-lezdo/ml-learning/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install torch torchvision transformers pillow
# !pip install torch transformers faiss-cpu pillow
# !pip install -q pdf2image git+https://github.com/huggingface/transformers.git qwen-vl-utils flash-attn
# !sudo apt-get install -y poppler-utils
# !pip install colpali-engine transformers pdf2image faiss-gpu
# !pip install timm
# !pip install --upgrade byaldi
# !pip install colpali-engine
# !pip install --upgrade transformers torchvision
# !pip install colpali_engine==0.1.1
# Out:
# ...
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#   Preparing metadata (setup.py) ... done
# ...
#   error: subprocess-exited-with-error
#
#   × python setup.py bdist_wheel did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# ...
#   ERROR: Failed building wheel for flash-attn
# ERROR: ERROR: Failed to build installable wheels for some pyproject.toml based projects (flash-attn)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# poppler-utils is already the newest version (22.02.0-2ubuntu0.5).
# 0 upgraded, 0 newly installed, 0 to remove and 49 not upgraded.
# ...
#   Using cached colpali_engine-0.3.2-py3-none-any.whl.metadata (13 kB)
# ...
# Using cached colpali_engine-0.3.2-py3-none-any.whl (37 kB)
# ...
#   Attempting uninstall: colpali-engine
# ...

# %%
# !sudo apt-get install poppler-utils
# !pip3 install colpali-engine==0.2.2 pdf2image pypdf pyvespa vespacli requests
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# poppler-utils is already the newest version (22.02.0-2ubuntu0.5).
# 0 upgraded, 0 newly installed, 0 to remove and 49 not upgraded.
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.5/294.5 kB 13.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.8/75.8 kB 6.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.7/47.7 MB 18.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 147.8/147.8 kB 11.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.0/78.0 kB 7.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 4.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.5/57.5 kB 5.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.4/76.4 kB 7.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 5.1 MB/s eta 0:00:00
# ...

# %% [markdown]
# CLIP

# %%
import torch
from transformers import CLIPProcessor, CLIPModel
from PIL import Image
from pdf2image import convert_from_path
torch.cuda.empty_cache()
# Check if CUDA (GPU) is available and set the device accordingly
device = "cuda" if torch.cuda.is_available() else "cpu"

# Load pre-trained CLIP model and processor from Hugging Face
model = CLIPModel.from_pretrained("openai/clip-vit-base-pa  tch32").to(device)
processor = CLIPProcessor.from_pretrained("openai/clip-vit-base-patch32")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/transformers/utils/import_utils.py in _get_module(self, module_name)
#    1602         ("tensorflow_text", (is_tensorflow_text_available, TENSORFLOW_TEXT_IMPORT_ERROR)),
# -> 1603         ("timm", (is_timm_available, TIMM_IMPORT_ERROR)),
#    1604         ("torchaudio", (is_torchaudio_available, TORCHAUDIO_IMPORT_ERROR)),
#
# /usr/lib/python3.10/importlib/__init__.py in import_module(name, package)
#     125             level += 1
# --> 126     return _bootstrap._gcd_import(name[level:], package, level)
#     127
#
# /usr/lib/python3.10/importlib/_bootstrap.py in _gcd_import(name, package, level)
#
# /usr/lib/python3.10/importlib/_bootstrap.py in _find_and_load(name, import_)
#
# /usr/lib/python3.10/importlib/_bootstrap.py in _find_and_load_unlocked(name, import_)
#
# ...

# %%
# import torch
# from transformers import CLIPProcessor, CLIPModel
# from PIL import Image
# from pdf2image import convert_from_path

# # Check if CUDA (GPU) is available and set the device accordingly
# device = "cuda" if torch.cuda.is_available() else "cpu"

# # Load pre-trained CLIP model and processor from Hugging Face
# model = CLIPModel.from_pretrained("openai/clip-vit-base-patch32").to(device)
# processor = CLIPProcessor.from_pretrained("openai/clip-vit-base-patch32")

# Convert PDF to images
images = convert_from_path("injury.pdf")

# Function to process images from a PDF and text queries
def process_pdf_images_text(images, text_queries):
    # Process the batch of images and text queries
    inputs = processor(text=text_queries, images=images, return_tensors="pt", padding=True).to(device)

    # Forward pass through the model for the batch
    outputs = model(**inputs)

    # Logits for batch similarity
    logits_per_image = outputs.logits_per_image  # Similarity between each image and text

    # For each image, find the most relevant text
    for i, image in enumerate(images):
        most_relevant_idx = logits_per_image[i].argmax()
        print(f"Most relevant text for image {i + 1}: {text_queries[most_relevant_idx]}")

# Define text queries
text_queries = ["medical"]

# Process the images converted from PDF and print relevant text for each image
process_pdf_images_text(images, text_queries)
# Out:
# Most relevant text for image 1: jenish
# Most relevant text for image 2: jenish
# Most relevant text for image 3: jenish
# Most relevant text for image 4: jenish
# Most relevant text for image 5: jenish
# Most relevant text for image 6: jenish
# Most relevant text for image 7: jenish
# Most relevant text for image 8: jenish
# Most relevant text for image 9: jenish
# Most relevant text for image 10: jenish

# %% [markdown]
# COlPali

# %%
# Install required libraries
# !pip install colpali-engine transformers pdf2image faiss-gpu
import torch
from colpali_engine.models import  ColPali, ColPaliProcessor
from pdf2image import convert_from_path
import faiss
from transformers import RagTokenizer, RagRetriever, RagSequenceForGeneration
torch.cuda.empty_cache()

# Step 1: Convert PDF pages to images using pdf2image

# Display an example image (optional)
# images[5].show()

# Step 2: Load ColPali model and processor
model_name = "vidore/colpali-v1.2"
# model = ColPali.from_pretrained(model_name, torch_dtype=torch.bfloat16, device_map="cuda:0").eval()
model = ColPali.from_pretrained(model_name, torch_dtype=torch.float32, device_map="cpu").eval()
# model = ColPali.from_pretrained(model_name, torch_dtype=torch.float32, device_map="cuda").eval()
processor = ColPaliProcessor.from_pretrained(model_name)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-5-afb9da5f4795> in <cell line: 4>()
#       2 # !pip install colpali-engine transformers pdf2image faiss-gpu
#       3 import torch
# ----> 4 from colpali_engine.models import  ColPali, ColPaliProcessor
#       5 from pdf2image import convert_from_path
#       6 import faiss
#
# ImportError: cannot import name 'ColPali' from 'colpali_engine.models' (/usr/local/lib/python3.10/dist-packages/colpali_engine/models/__init__.py)
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# Install required libraries
# !pip install colpali-engine transformers pdf2image faiss-gpu

# import torch
# from colpali_engine.models import ColPali, ColPaliProcessor
# from pdf2image import convert_from_path
# import faiss
# from transformers import RagTokenizer, RagRetriever, RagSequenceForGeneration
# torch.cuda.empty_cache()

# # Step 1: Convert PDF pages to images using pdf2image
# images = convert_from_path("files/injury.pdf")

# # Display an example image (optional)
# # images[5].show()

# # Step 2: Load ColPali model and processor
# model_name = "vidore/colpali-v1.2"
# # model = ColPali.from_pretrained(model_name, torch_dtype=torch.bfloat16, device_map="cuda:0").eval()
# model = ColPali.from_pretrained(model_name, torch_dtype=torch.float32, device_map="cpu").eval()
# # model = ColPali.from_pretrained(model_name, torch_dtype=torch.float32, device_map="cuda").eval()
# processor = ColPaliProcessor.from_pretrained(model_name)

# # Step 3: Process images and generate embeddings
# image_embeddings = []

# for image in images:
#     # Convert image to model input format
#     processed_image = processor.process_images([image]).to(model.device)

#     # Get embeddings from the model
#     with torch.no_grad():
#         embedding = model(**processed_image).cpu().numpy()
#         image_embeddings.append(embedding)

# # Convert list of embeddings into a suitable format for FAISS
# image_embeddings = torch.cat([torch.tensor(emb) for emb in image_embeddings], dim=0).numpy()

# # Step 4: Initialize FAISS Index and add embeddings
# d = image_embeddings.shape[1]  # Get embedding dimensions
# index = faiss.IndexFlatL2(d)  # Using L2 (Euclidean distance)

# # Add embeddings to the FAISS index
# index.add(image_embeddings)

# # Step 5: Query function to retrieve relevant images using ColPali and FAISS
# def retrieve_documents(query, k=3):
#     # Process the query using ColPali processor
#     processed_query = processor.process_queries([query]).to(model.device)

#     # Get query embeddings
#     with torch.no_grad():
#         query_embedding = model(**processed_query).cpu().numpy()

#     # Perform FAISS search for the top-k similar images
#     distances, indices = index.search(query_embedding, k)

#     # Return the indices of the top-k retrieved images
#     return indices

# # Example query
# query = "What is the role of youth in climate action?"
# top_k_indices = retrieve_documents(query, k=5)

# # Fetch the top-k images (optional: for visualization or further use)
# retrieved_images = [images[i] for i in top_k_indices.flatten()]

# # Display retrieved images (optional)
# # for img in retrieved_images:
# #     img.show()

# # Step 6: Load RAG model and tokenizer for response generation
# rag_tokenizer = RagTokenizer.from_pretrained("facebook/rag-sequence-base")
# rag_retriever = RagRetriever.from_pretrained("facebook/rag-sequence-base")
# rag_model = RagSequenceForGeneration.from_pretrained("facebook/rag-sequence-base")

# # Step 7: Prepare the input query for the RAG model
# input_ids = rag_tokenizer(query, return_tensors="pt").input_ids

# # Generate response using the RAG model
# generated = rag_model.generate(input_ids, num_beams=2, max_length=100, do_sample=True)

# # Decode and print the generated response
# output = rag_tokenizer.batch_decode(generated, skip_special_tokens=True)
# print(output)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# `config.hidden_act` is ignored, you should use `config.hidden_activation` instead.
# Gemma's activation function will be set to `gelu_pytorch_tanh`. Please, use
# `config.hidden_activation` if you want to override this behaviour.
# See https://github.com/huggingface/transformers/pull/29402 for more details.
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]

# %%
# Step 3: Process images and generate embeddings
images = convert_from_path("files/injury.pdf")

image_embeddings = []

for image in images:
    # Process and get embeddings for one image at a time
    processed_image = processor.process_images([image]).to(model.device)
    with torch.no_grad():
        embedding = model(**processed_image).cpu().numpy()
        image_embeddings.append(embedding)

# Convert list of embeddings into a suitable format for FAISS
image_embeddings = torch.cat([torch.tensor(emb) for emb in image_embeddings], dim=0).numpy()

# Step 4: Initialize FAISS Index and add embeddings
d = image_embeddings.shape[1]  # Get embedding dimensions
index = faiss.IndexFlatL2(d)  # Using L2 (Euclidean distance)

# Add embeddings to the FAISS index
index.add(image_embeddings)

# Step 5: Query function to retrieve relevant images using ColPali and FAISS
def retrieve_documents(query, k=3):
    # Process the query using ColPali processor
    processed_query = processor.process_queries([query]).to(model.device)

    # Get query embeddings
    with torch.no_grad():
        query_embedding = model(**processed_query).cpu().numpy()

    # Perform FAISS search for the top-k similar images
    distances, indices = index.search(query_embedding, k)

    # Return the indices of the top-k retrieved images
    return indices

# Example query
query = "What is the role of youth in climate action?"
top_k_indices = retrieve_documents(query, k=5)

# Fetch the top-k images (optional: for visualization or further use)
retrieved_images = [images[i] for i in top_k_indices.flatten()]

# Display retrieved images (optional)
# for img in retrieved_images:
#     img.show()

# Step 6: Load RAG model and tokenizer for response generation
rag_tokenizer = RagTokenizer.from_pretrained("facebook/rag-sequence-base")
rag_retriever = RagRetriever.from_pretrained("facebook/rag-sequence-base")
rag_model = RagSequenceForGeneration.from_pretrained("facebook/rag-sequence-base")

# Step 7: Prepare the input query for the RAG model
input_ids = rag_tokenizer(query, return_tensors="pt").input_ids

# Generate response using the RAG model
generated = rag_model.generate(input_ids, num_beams=2, max_length=100, do_sample=True)

# Decode and print the generated response
output = rag_tokenizer.batch_decode(generated, skip_special_tokens=True)
print(output)
# Out:
# You are passing both `text` and `images` to `PaliGemmaProcessor`. The processor expects special image tokens in the text, as many tokens as there are images per each text. It is recommended to add `` tokens in the very beginning of your text and `<bos>` token after that. For this call, we will infer how many images each text has and add special tokens.
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-3-165975d49009> in <cell line: 4>()
#       8     # Get embeddings from the model
#       9     with torch.no_grad():
# ---> 10         embedding = model(**processed_image).cpu().numpy()
#      11         image_embeddings.append(embedding)
#      12
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1551             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
# ...

# %%
# !pip install colpali-engine

# %%
from typing import cast

import torch
from PIL import Image

from colpali_engine.models import ColPali, ColPaliProcessor

model_name = "vidore/colpali-v1.2"

model = ColPali.from_pretrained(
    model_name,
    torch_dtype=torch.float32,
    device_map="cpu",  # or "mps" if on Apple Silicon
).eval()
processor = ColPaliProcessor.from_pretrained(model_name)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/transformers/utils/import_utils.py in _get_module(self, module_name)
#    1602         ("tensorflow_text", (is_tensorflow_text_available, TENSORFLOW_TEXT_IMPORT_ERROR)),
# -> 1603         ("timm", (is_timm_available, TIMM_IMPORT_ERROR)),
#    1604         ("torchaudio", (is_torchaudio_available, TORCHAUDIO_IMPORT_ERROR)),
#
# /usr/lib/python3.10/importlib/__init__.py in import_module(name, package)
#     125             level += 1
# --> 126     return _bootstrap._gcd_import(name[level:], package, level)
#     127
#
# /usr/lib/python3.10/importlib/_bootstrap.py in _gcd_import(name, package, level)
#
# /usr/lib/python3.10/importlib/_bootstrap.py in _find_and_load(name, import_)
#
# /usr/lib/python3.10/importlib/_bootstrap.py in _find_and_load_unlocked(name, import_)
#
# ...

# %%
from typing import cast

import torch
from PIL import Image

from colpali_engine.models import ColPali, ColPaliProcessor
from byaldi import RAGMultiModalModel

model_name = "vidore/colpali"

model = ColPali.from_pretrained(
    model_name,
    torch_dtype=torch.float32,
    device_map="cpu",  # or "mps" if on Apple Silicon
).eval()

# model = ColPali.from_pretrained(model_name, torch_dtype=torch.float32, device_map="cpu").eval()
RAG = RAGMultiModalModel.from_pretrained("vidore/colpali")
# processor = ColPaliProcessor.from_pretrained(model_name)

# Your inputs
images = [
    Image.new("RGB", (32, 32), color="white"),
    Image.new("RGB", (16, 16), color="black"),
]
queries = [
    "Is attention really all you need?",
    "Are Benjamin, Antoine, Merve, and Jo best friends?",
]

# Process the inputs
batch_images = processor.process_images(images).to(model.device)
batch_queries = processor.process_queries(queries).to(model.device)

# Forward pass
with torch.no_grad():
    image_embeddings = model(**batch_images)
    querry_embeddings = model(**batch_queries)

scores = processor.score_multi_vector(querry_embeddings, image_embeddings)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# `config.hidden_act` is ignored, you should use `config.hidden_activation` instead.
# Gemma's activation function will be set to `gelu_pytorch_tanh`. Please, use
# `config.hidden_activation` if you want to override this behaviour.
# See https://github.com/huggingface/transformers/pull/29402 for more details.
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]

# %% [markdown]
# # New Section

# %%
# !sudo apt-get install poppler-utils
# !pip install --upgrade transformers torch torchvision
# !pip install colpali-engine
# !pip install --upgrade byaldi
# !pip install timm
# !pip install colpali-engine
# !pip3 install colpali-engine==0.2.2 pdf2image pypdf pyvespa vespacli requests
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following NEW packages will be installed:
#   poppler-utils
# 0 upgraded, 1 newly installed, 0 to remove and 49 not upgraded.
# Need to get 186 kB of archives.
# After this operation, 696 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 poppler-utils amd64 22.02.0-2ubuntu0.5 [186 kB]
# Fetched 186 kB in 4s (49.2 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# ...

# %% [markdown]
# # New Section

# %%
import torch
from torch.utils.data import DataLoader
from tqdm import tqdm
from transformers import AutoProcessor
from PIL import Image
from io import BytesIO
from colpali_engine.models.paligemma_colbert_architecture import ColPali
from colpali_engine.utils.colpali_processing_utils import (
    process_images,
    process_queries,
)
from colpali_engine.utils.image_utils import scale_image, get_base64_image

# %%
if torch.cuda.is_available():
    device = torch.device("cuda")
    type = torch.bfloat16
elif torch.backends.mps.is_available():
    device = torch.device("mps")
    type = torch.float32
else:
    device = torch.device("cpu")
    type = torch.float32

# %%
torch.cuda.empty_cache()

# Step 1: Convert PDF pages to images using pdf2image

# Display an example image (optional)
# images[5].show()

# Step 2: Load ColPali model and processor
model_name = "vidore/colpali-v1.2"
# model = ColPali.from_pretrained(model_name, torch_dtype=torch.bfloat16, device_map="cuda:0").eval()
model = ColPali.from_pretrained(model_name, torch_dtype=torch.float16, device_map="cpu").eval()
# model = ColPali.from_pretrained(model_name, torch_dtype=torch.float32, device_map="cuda").eval()
processor = AutoProcessor.from_pretrained(model_name)

# model_name = "vidore/colpali-v1.2"  # Use smaller models if available (e.g., "vidore/colpali-v1.1")
# model = ColPali.from_pretrained(model_name, torch_dtype=torch.float16, device_map="cpu").eval()
# processor = AutoProcessor.from_pretrained(model_name)

# model_name = "vidore/colpali-v1.2"
# model = ColPali.from_pretrained("vidore/colpaligemma-3b-pt-448-base", torch_dtype=type).eval()
# model.load_adapter(model_name)
# model = model.eval()
# model.to(device)
# processor = AutoProcessor.from_pretrained(model_name)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# adapter_config.json:   0%|          | 0.00/750 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.01k [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/66.3k [00:00<?, ?B/s]
# ...
# model-00001-of-00002.safetensors:   0%|          | 0.00/4.99G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/862M [00:00<?, ?B/s]
# `config.hidden_act` is ignored, you should use `config.hidden_activation` instead.
# ...

# %%
import requests
from pdf2image import convert_from_path
from pypdf import PdfReader


def download_pdf(url):
    response = requests.get(url)
    if response.status_code == 200:
        return BytesIO(response.content)
    else:
        raise Exception(f"Failed to download PDF: Status code {response.status_code}")


def get_pdf_images(pdf_url):
    # Download the PDF
    pdf_file = download_pdf(pdf_url)
    # Save the PDF temporarily to disk (pdf2image requires a file path)
    with open("temp.pdf", "wb") as f:
        f.write(pdf_file.read())
    reader = PdfReader("temp.pdf")
    page_texts = []
    for page_number in range(len(reader.pages)):
        page = reader.pages[page_number]
        text = page.extract_text()
        page_texts.append(text)
    images = convert_from_path("temp.pdf")
    assert len(images) == len(page_texts)
    return (images, page_texts)

# %%
sample_pdfs = [
    {
        "title": "ColBERTv2: Effective and Efficient Retrieval via Lightweight Late Interaction",
        "url": "https://arxiv.org/pdf/2112.01488.pdf",
        "authors": "Keshav Santhanam, Omar Khattab, Jon Saad-Falcon, Christopher Potts, Matei Zaharia",
    },
    {
        "title": "ColBERT: Efficient and Effective Passage Search via Contextualized Late Interaction over BERT",
        "url": "https://arxiv.org/pdf/2004.12832.pdf",
        "authors": "Omar Khattab, Matei Zaharia",
    },
]

# %%
for pdf in sample_pdfs:
    page_images, page_texts = get_pdf_images(pdf["url"])
    pdf["images"] = page_images
    pdf["texts"] = page_texts

# %%
from IPython.display import display

display(scale_image(sample_pdfs[0]["images"][0], 720))
# Out:
# <PIL.Image.Image image mode=RGB size=509x720>

# %%
for pdf in sample_pdfs:
    page_embeddings = []
    dataloader = DataLoader(
        pdf["images"],
        batch_size=32,  # Reduced batch size
        shuffle=False,
        collate_fn=lambda x: process_images(processor, x),
    )
    for batch_doc in tqdm(dataloader):
        with torch.no_grad():
            batch_doc = {k: v.to(model.device) for k, v in batch_doc.items()}
            embeddings_doc = model(**batch_doc)
            page_embeddings.extend(list(torch.unbind(embeddings_doc.to("cpu"))))

        # Clean up GPU memory
        torch.cuda.empty_cache()

    pdf["embeddings"] = page_embeddings
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]

# %%
import numpy as np
from typing import Dict, List
from binascii import hexlify


def binarize_token_vectors_hex(vectors: List[torch.Tensor]) -> Dict[str, str]:
    vespa_tensor = list()
    for page_id in range(0, len(vectors)):
        page_vector = vectors[page_id]
        binarized_token_vectors = np.packbits(
            np.where(page_vector > 0, 1, 0), axis=1
        ).astype(np.int8)
        for patch_index in range(0, len(page_vector)):
            values = str(
                hexlify(binarized_token_vectors[patch_index].tobytes()), "utf-8"
            )
            if (
                values == "00000000000000000000000000000000"
            ):  # skip empty vectors due to padding of batch
                continue
            vespa_tensor_cell = {
                "address": {"page": page_id, "patch": patch_index},
                "values": values,
            }
            vespa_tensor.append(vespa_tensor_cell)

    return vespa_tensor

# %%
vespa_feed = []
for idx, pdf in enumerate(sample_pdfs):
    images_base_64 = []
    for image in pdf["images"]:
        images_base_64.append(get_base64_image(image, add_url_prefix=False))
    pdf["images_base_64"] = images_base_64
    doc = {
        "fields": {
            "url": pdf["url"],
            "title": pdf["title"],
            "images": pdf["images_base_64"],
            "texts": pdf["texts"],  # Array of text per page
            "colbert": {  # Colbert embeddings per page
                "blocks": binarize_token_vectors_hex(pdf["embeddings"])
            },
        }
    }
    vespa_feed.append(doc)

# %%
vespa_feed[0]["fields"]["colbert"]["blocks"][0:5]

# %% [markdown]
# COlpali ENGINE

# %%
# !pip install colpali_engine==0.1.1

# %%
# Install required packages if not already installed
# !pip install torch transformers pillow typer
# !pip install -q pdf2image git+https://github.com/huggingface/transformers.git qwen-vl-utils flash-attn
# !sudo apt-get install -y poppler-utils
# !pip install torch transformers pillow typer
# !pip install torch transformers pillow typer requests
# This model checkpoint is compatible with version 0.1.1, but not more recent versions of the inference lib
# !pip install colpali_engine==0.1.1
# Out:
# ...
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# poppler-utils is already the newest version (22.02.0-2ubuntu0.5).
# 0 upgraded, 0 newly installed, 0 to remove and 49 not upgraded.
# ...

# %%
# Install required packages if not already installed

import torch
from torch.utils.data import DataLoader
from tqdm import tqdm
from transformers import AutoProcessor
from PIL import Image
import requests
from io import BytesIO

# Assuming custom classes and methods are available in Colab.
from colpali_engine.models.paligemma_colbert_architecture import ColPali
# from colpali_engine.trainer.retrieval_evaluator import CustomEvaluator
from colpali_engine.utils.colpali_processing_utils import process_images, process_queries
model_name = "vidore/colpali"
model = ColPali.from_pretrained(
        "vidore/colpaligemma-3b-mix-448-base",
        torch_dtype=torch.float16,  # Use float16 for better compatibility in Colab
        device_map="cuda" if torch.cuda.is_available() else "cpu"
    ).eval()

model.load_adapter(model_name)
processor = AutoProcessor.from_pretrained(model_name)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# `config.hidden_act` is ignored, you should use `config.hidden_activation` instead.
# Gemma's activation function will be set to `gelu_pytorch_tanh`. Please, use
# `config.hidden_activation` if you want to override this behaviour.
# See https://github.com/huggingface/transformers/pull/29402 for more details.
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# ...

# %%
# This model checkpoint is compatible with version 0.1.1, but not more recent versions of the inference lib
# !pip install colpali_engine==0.1.1

# %%
def main():
    """Example script to run inference with ColPali in Colab using image URLs"""

    # Load model
    # List of image URLs
    image_urls = [
        'https://www.lifewire.com/thmb/iqJGWF1zAbcC-VksJq0hkCPwUk8=/1359x0/filters:no_upscale():max_bytes(150000):strip_icc():format(webp)/pdf-editor-online-f7f9183e278b40a5a75293201c83902e.png'
    ]

    # Load images from URLs
    images = []
    for url in image_urls:
        response = requests.get(url)
        image = Image.open(BytesIO(response.content)).convert("RGB")
        images.append(image)

    queries = ["From which university does James V. Fiorca come?", "Who is the Japanese prime minister?"]

    # Process and run inference - docs
    dataloader = DataLoader(
        images,
        batch_size=4,
        shuffle=False,
        collate_fn=lambda x: process_images(processor, x),
    )
    qs = []
    ds = []
    for batch_query in dataloader:
        with torch.no_grad():
            batch_query = {k: v.to(model.device) for k, v in batch_query.items()}
            embeddings_query = model(**batch_query)
        qs.extend(list(torch.unbind(embeddings_query.to("cpu"))))

    # run evaluation
    retriever_evaluator = CustomEvaluator(is_multi_vector=True)
    scores = retriever_evaluator.evaluate(qs, ds)
    print(scores.argmax(axis=1))

main()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-12-6ed0351dd680> in <cell line: 1>()
# ----> 1 from colpali_engine.trainer.retrieval_evaluator import CustomEvaluator
#       2 def main():
#       3     """Example script to run inference with ColPali in Colab using image URLs"""
#       4
#       5     # Load model
#
# /usr/local/lib/python3.10/dist-packages/colpali_engine/trainer/retrieval_evaluator.py in <module>
#       1 import torch
# ----> 2 from mteb.evaluation.evaluators import RetrievalEvaluator
#       3
#       4
#       5 class CustomEvaluator:
#
# ModuleNotFoundError: No module named 'mteb'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# ...

# %%
pip install gradio_client

# %%
from gradio_client import Client, handle_file

client = Client("p3nguknight/colpali-pixtral")
result = client.predict(
		files=[handle_file('https://arxiv.org/pdf/2112.01488')],
		api_name="/index"
)
print(result)
# Out:
# Loaded as API: https://p3nguknight-colpali-pixtral.hf.space ✔
# Uploaded and converted 20 pages

# %%
from gradio_client import Client

client = Client("p3nguknight/colpali-pixtral")
result = client.predict(
		query="first page",
		k=1,
		api_name="/retrieve"
)
print(result)
# Out:
# Loaded as API: https://p3nguknight-colpali-pixtral.hf.space ✔
# ---------------------------------------------------------------------------
# AppError                                  Traceback (most recent call last)
# <ipython-input-11-61a6662a3029> in <cell line: 4>()
#       2
#       3 client = Client("p3nguknight/colpali-pixtral")
# ----> 4 result = client.predict(
#       5                 query="first page",
#       6                 k=1,
#
# /usr/local/lib/python3.10/dist-packages/gradio_client/client.py in predict(self, api_name, fn_index, *args, **kwargs)
#     474         return self.submit(
#     475             *args, api_name=api_name, fn_index=fn_index, **kwargs
# --> 476         ).result()
#     477
#     478     def new_helper(self, fn_index: int) -> Communicator:
#
# /usr/local/lib/python3.10/dist-packages/gradio_client/client.py in result(self, timeout)
#    1511             >> 9
#    1512         """
# -> 1513         return super().result(timeout=timeout)
# ...
